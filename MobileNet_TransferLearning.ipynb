# %% [markdown]
# **Keras**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import imagenet_utils
from IPython.display import Image

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1

# %%
# Directory to dataset in drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
model = tf.keras.applications.MobileNet()
# Out:
# ...
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1 (Conv2D)                       │ (None, 112, 112, 32)        │             864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_bn (BatchNormalization)        │ (None, 112, 112, 32)        │             128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1_relu (ReLU)                    │ (None, 112, 112, 32)        │               0 │
# ...

# %%
def prepare_image(file):
    img_path = ''
    img = image.load_img(img_path + file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    print(img_array.shape)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    print(img_array_expanded_dims.shape)
    return tf.keras.applications.mobilenet.preprocess_input(img_array_expanded_dims)

# %% [markdown]
# **https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a**

# %% [markdown]
# # **List of all 1000 categories from ImageNet Competition**

# %%
Image(filename='/content/gdrive/MyDrive/input_image-1.png', width=300,height=200)

# %%
preprocessed_image = prepare_image('/content/gdrive/MyDrive/input_image-1.png')
predictions = model.predict(preprocessed_image)
# Out:
# (224, 224, 3)
# (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step

# %%
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# [[('n02129604', 'tiger', 0.7672177),
#   ('n02123159', 'tiger_cat', 0.23184024),
#   ('n02127052', 'lynx', 0.00033089652),
#   ('n02123045', 'tabby', 0.00022221953),
#   ('n02128925', 'jaguar', 0.00011508187)]]

# %%
Image(filename='/content/gdrive/MyDrive/python .jpeg', width=300,height=200)

# %%
preprocessed_image = prepare_image('/content/gdrive/MyDrive/python .jpeg')
predictions = model.predict(preprocessed_image)
# Out:
# (224, 224, 3)
# (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
results = imagenet_utils.decode_predictions(predictions)
results
# Out:
# [[('n01744401', 'rock_python', 0.56604403),
#   ('n01742172', 'boa_constrictor', 0.1650556),
#   ('n01740131', 'night_snake', 0.06891777),
#   ('n01739381', 'vine_snake', 0.06350771),
#   ('n01753488', 'horned_viper', 0.038002994)]]
